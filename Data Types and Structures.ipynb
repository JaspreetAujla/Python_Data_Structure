# %% [markdown]
# ## **# Practical Questions**

# %%
# 1.Write a code to create a string with your name and print it?

name = "Jassie"
print(name)
# Out:
# Jassie

# %%
# 2.Write a code to find the length of the string "Hello World"?

print("The length of the string is :" , len("Hello World"))
# Out:
# The length of the string is : 11

# %%
# 3.Write a code to slice the first 3 characters from the string "Python Programming"?

string = "Python Programming"
print("The first 3 characters from the string is :" , string[0:3])
# Out:
# The first 3 characters from the string is : Pyt

# %%
# 4.Write a code to convert the string "hello" to uppercase?

string = "hello"
print("The string hello in uppercase is:",string.upper())
# Out:
# The string hello in uppercase is: HELLO

# %%
# 5.Write a code to replace the word "apple" with "orange" in the string "I like apple"?

str = "I like apple"
print( "The string I like apple is :",str.replace ("apple" , "orange"))
# Out:
# The string I like apple is : I like orange

# %%
# 6.Write a code to create a list with numbers 1 to 5 and print it?

list = [1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7.Write a code to append the number 10 to the list [1, 2, 3, 4]?

list = [1,2,3,4]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8.Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

list = [1,2,3,4,5]
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5]

# %%
# 9.Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

list = ['a','b','c','d']
print("The Second element in the list is: " , list[1])
# Out:
# The Second element in the list is:  b

# %%
# 10.Write a code to reverse the list [10, 20, 30, 40, 50]?

list =  [10, 20, 30, 40, 50]
list.reverse()
print("The reverse list are:" , (list))
# Out:
# The reverse list are: [50, 40, 30, 20, 10]

# %%
# 11.Write a code to create a tuple with the elements 100, 200, 300 and print it.

tuple = (100,200,300)
print(tuple)
# Out:
# (100, 200, 300)

# %%
# 12.Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

tuple = ('red', 'green', 'blue', 'yellow')
print("The second-to-last element of the tuple is:" , tuple[-2])
# Out:
# The second-to-last element of the tuple is: blue

# %%
# 13.Write a code to find the minimum number in the tuple (10, 20, 5, 15).

num = (10, 20, 5, 15)
print("The minimum number in the tuple is:" , min(num))
# Out:
# The minimum number in the tuple is: 5

# %%
# 14.Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

tuple = ('dog', 'cat', 'rabbit')
print("The index of the element cat in the tuple is:" , tuple.index('cat'))
# Out:
# The index of the element cat in the tuple is: 1

# %%
# 15.Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

fruits = ("apple" , "banana" , "orange")
print("The KIWI is present in tuple:\n",("kiwi" in tuple))

fruits = ("apple" , "banana" ,"kiwi" ,"orange", "mango")
print("The KIWI is present in tuple:\n",("kiwi" in fruits))
# Out:
# The KIWI is present in tuple:
#  False
# The KIWI is present in tuple:
#  True

# %%
# 16.Write a code to create a set with the elements 'a', 'b', 'c' and print it.

set ={"a", "b", "c"}
print(set)
# Out:
# {'a', 'b', 'c'}

# %%
# 17.Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

num = {1, 2, 3, 4, 5}
num.clear()
print("Clear the elements from the set:" ,(num))
# Out:
# clear the elements from the set: set()

# %%
# 18.Write a code to remove the element 4 from the set {1, 2, 3, 4}.

number = {1, 2, 3, 4}
number.remove(4)
print("Remove the element 4 from the set:" ,(number))
# Out:
# Remove the element 4 from the set: {1, 2, 3}

# %%
# 19.Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

set1 = {1, 2, 3}
set2 = {3, 4, 5}
print("The union of two sets:" , set1.union(set2))
# Out:
# The union of two sets: {1, 2, 3, 4, 5}

# %%
# 20.Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}

set1 = {1, 2, 3, 4}
set2 = {2, 3, 4, 5}
print("The intersection of two sets:" , set1.intersection(set2))
# Out:
# The intersection of two sets: {2, 3, 4}

# %%
# 21.Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

dict = {"name" : "Jassie","age" : 24,"city" : "Delhi"}
print(dict)
# Out:
# {'name': 'Jassie', 'age': 24, 'city': 'Delhi'}

# %%
# 22.Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

dict = {'name': 'John', 'age': 25}
dict["country"] = "USA"
print(dict)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# 23.Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

dict = {'name': 'Alice', 'age': 30}
print("The value associated with the key name is:" , dict["name"])
# Out:
# The value associated with the key name is: Alice

# %%
# 24.Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
person.pop('age')

print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# 25.Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

key = {'name': 'Sanjana', 'city': 'Paris'}
print("The key city exists in the dictionary:\n" , "city" in key)

key = {'name': 'Sanjana', 'age': 25}
print("The key city exists in the dictionary:\n" , "city" in key)
# Out:
# The key city exists in the dictionary:
#  True
# The key city exists in the dictionary:
#  False

# %%
# 26.Write a code to create a list, a tuple, and a dictionary, and print them all.

list = [1,2,3,4,5]
print("This is the list element:\n",(list))
tuple = (1,2,3,4,5)
print("This is the tuple element:\n",(tuple))
dict = {"name" : "Jassie", "age" : 24 , "city" : "Delhi"}
print("This is the list element:\n",(dict))
# Out:
# This is the list element:
#  [1, 2, 3, 4, 5]
# This is the tuple element:
#  (1, 2, 3, 4, 5)
# This is the list element:
#  {'name': 'Jassie', 'age': 24, 'city': 'Delhi'}

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)

import random
numbers = random.sample(range(1, 101), 5)
numbers.sort()

print("The list of 5 random numbers between 1 and 100:", (numbers))
# Out:
# The list of 5 random numbers between 1 and 100: [35, 42, 45, 57, 61]

# %%
# 28.Write a code to create a list with strings and print the element at the third index.

list = ["Apple" , "Banana" , "Pineapple" , "Kiwi" , "Mango", "Orange"]
print("The element at the third index is:" , list[2])
# Out:
# The element at the third index is: Pineapple

# %%
# 29.Write a code to combine two dictionaries into one and print the result.

dict1 = {'a': 1, 'b': 2 , 'c' :3}
dict2 = {'d': 4, 'e': 5 , 'f':6}

combined_dict = {**dict1, **dict2}

print(combined_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
# 30.Write a code to convert a list of strings into a set.

my_list = ["BMW" , "Rolls Royce" , "Defender" , "Mercedes" ,"Supra" , "Honda City"]
print(set(my_list))
# Out:
# {'Rolls Royce', 'Defender', 'Honda City', 'Supra', 'BMW', 'Mercedes'}
